# %%
# !pip install transformers torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting transformers
#   Downloading transformers-5.3.0-py3-none-any.whl.metadata (32 kB)
# Collecting torch
#   Downloading torch-2.10.0-cp314-cp314-win_amd64.whl.metadata (31 kB)
# Collecting huggingface-hub<2.0,>=1.3.0 (from transformers)
#   Downloading huggingface_hub-1.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\lenovo\appdata\roaming\python\python314\site-packages (from transformers) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\appdata\roaming\python\python314\site-packages (from transformers) (25.0)
# Collecting pyyaml>=5.1 (from transformers)
#   Using cached pyyaml-6.0.3-cp314-cp314-win_amd64.whl.metadata (2.4 kB)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\lenovo\appdata\roaming\python\python314\site-packages (from transformers) (2026.1.15)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Collecting typer (from transformers)
#   Downloading typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Using cached safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\lenovo\appdata\roaming\python\python314\site-packages (from transformers) (4.67.1)
# Collecting filelock>=3.10.0 (from huggingface-hub<2.0,>=1.3.0->transformers)
#   Downloading filelock-3.25.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<2.0,>=1.3.0->transformers)
#   Downloading fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.3.2 (from huggingface-hub<2.0,>=1.3.0->transformers)
#   Downloading hf_xet-1.3.2-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Collecting httpx<1,>=0.23.0 (from huggingface-hub<2.0,>=1.3.0->transformers)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\lenovo\appdata\roaming\python\python314\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.15.0)
# Collecting anyio (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers)
#   Using cached anyio-4.12.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: certifi in c:\users\lenovo\appdata\roaming\python\python314\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.1.4)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in c:\users\lenovo\appdata\roaming\python\python314\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting jinja2 (from torch)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting setuptools (from torch)
#   Downloading setuptools-82.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: colorama in c:\users\lenovo\appdata\roaming\python\python314\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading markupsafe-3.0.3-cp314-cp314-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: click>=8.2.1 in c:\users\lenovo\appdata\roaming\python\python314\site-packages (from typer->transformers) (8.3.1)
# Collecting shellingham>=1.3.0 (from typer->transformers)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=12.3.0 (from typer->transformers)
#   Downloading rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer->transformers)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer->transformers)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenovo\appdata\roaming\python\python314\site-packages (from rich>=12.3.0->typer->transformers) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading transformers-5.3.0-py3-none-any.whl (10.7 MB)
#    ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#    -------- ------------------------------- 2.4/10.7 MB 11.3 MB/s eta 0:00:01
#    ------------------------- -------------- 6.8/10.7 MB 19.4 MB/s eta 0:00:01
#    ---------------------------------------- 10.7/10.7 MB 19.5 MB/s  0:00:00
# Downloading huggingface_hub-1.6.0-py3-none-any.whl (612 kB)
#    ---------------------------------------- 0.0/612.9 kB ? eta -:--:--
#    ---------------------------------------- 612.9/612.9 kB 17.0 MB/s  0:00:00
# Downloading hf_xet-1.3.2-cp37-abi3-win_amd64.whl (3.6 MB)
#    ---------------------------------------- 0.0/3.6 MB ? eta -:--:--
#    ---------------------------------------- 3.6/3.6 MB 18.4 MB/s  0:00:00
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 33.8 MB/s  0:00:00
# Downloading torch-2.10.0-cp314-cp314-win_amd64.whl (113.8 MB)
#    ---------------------------------------- 0.0/113.8 MB ? eta -:--:--
#    - -------------------------------------- 4.7/113.8 MB 22.8 MB/s eta 0:00:05
#    -- ------------------------------------- 8.4/113.8 MB 20.4 MB/s eta 0:00:06
#    ----- ---------------------------------- 15.5/113.8 MB 25.1 MB/s eta 0:00:04
#    ------- -------------------------------- 21.2/113.8 MB 26.0 MB/s eta 0:00:04
#    --------- ------------------------------ 26.5/113.8 MB 25.7 MB/s eta 0:00:04
#    ---------- ----------------------------- 30.7/113.8 MB 24.8 MB/s eta 0:00:04
#    ------------ --------------------------- 35.4/113.8 MB 24.5 MB/s eta 0:00:04
#    ------------- -------------------------- 38.3/113.8 MB 23.2 MB/s eta 0:00:04
#    -------------- ------------------------- 41.2/113.8 MB 23.5 MB/s eta 0:00:04
#    --------------- ------------------------ 45.4/113.8 MB 22.0 MB/s eta 0:00:04
#    ----------------- ---------------------- 50.3/113.8 MB 21.8 MB/s eta 0:00:03
#    ------------------- -------------------- 55.8/113.8 MB 22.1 MB/s eta 0:00:03
#    --------------------- ------------------ 60.3/113.8 MB 22.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 62.7/113.8 MB 21.8 MB/s eta 0:00:03
#    ---------------------- ----------------- 65.3/113.8 MB 20.8 MB/s eta 0:00:03
#    ------------------------ --------------- 69.2/113.8 MB 21.0 MB/s eta 0:00:03
#    ------------------------- -------------- 73.4/113.8 MB 20.5 MB/s eta 0:00:02
#    --------------------------- ------------ 78.4/113.8 MB 20.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 82.6/113.8 MB 20.6 MB/s eta 0:00:02
#    ------------------------------ --------- 85.7/113.8 MB 20.4 MB/s eta 0:00:02
#    ------------------------------ --------- 88.1/113.8 MB 19.8 MB/s eta 0:00:02
#    -------------------------------- ------- 92.8/113.8 MB 20.1 MB/s eta 0:00:02
#    --------------------------------- ------ 94.9/113.8 MB 19.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 97.8/113.8 MB 19.3 MB/s eta 0:00:01
#    ---------------------------------- ---- 100.9/113.8 MB 19.1 MB/s eta 0:00:01
#    ------------------------------------ -- 106.2/113.8 MB 19.3 MB/s eta 0:00:01
#    --------------------------------------  111.1/113.8 MB 19.4 MB/s eta 0:00:01
#    --------------------------------------  113.5/113.8 MB 19.6 MB/s eta 0:00:01
#    --------------------------------------  113.5/113.8 MB 19.6 MB/s eta 0:00:01
#    --------------------------------------  113.5/113.8 MB 19.6 MB/s eta 0:00:01
#    ---------------------------------------- 113.8/113.8 MB 17.7 MB/s  0:00:06
# Downloading filelock-3.25.0-py3-none-any.whl (26 kB)
# Downloading fsspec-2026.2.0-py3-none-any.whl (202 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Using cached pyyaml-6.0.3-cp314-cp314-win_amd64.whl (156 kB)
# Using cached safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached anyio-4.12.1-py3-none-any.whl (113 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading markupsafe-3.0.3-cp314-cp314-win_amd64.whl (15 kB)
# Downloading setuptools-82.0.0-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 22.4 MB/s  0:00:00
# Downloading typer-0.24.1-py3-none-any.whl (56 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading rich-14.3.3-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Installing collected packages: mpmath, sympy, shellingham, setuptools, safetensors, pyyaml, networkx, mdurl, MarkupSafe, hf-xet, h11, fsspec, filelock, anyio, annotated-doc, markdown-it-py, jinja2, httpcore, torch, rich, httpx, typer, huggingface-hub, tokenizers, transformers
#
#    ----------------------------------------  0/25 [mpmath]
#    ----------------------------------------  0/25 [mpmath]
#    ----------------------------------------  0/25 [mpmath]
#    ----------------------------------------  0/25 [mpmath]
#    ----------------------------------------  0/25 [mpmath]
#    ----------------------------------------  0/25 [mpmath]
#    ----------------------------------------  0/25 [mpmath]
#    ----------------------------------------  0/25 [mpmath]
#    ----------------------------------------  0/25 [mpmath]
#    ----------------------------------------  0/25 [mpmath]
#    ----------------------------------------  0/25 [mpmath]
#    ----------------------------------------  0/25 [mpmath]
#    ----------------------------------------  0/25 [mpmath]
#    ----------------------------------------  0/25 [mpmath]
#    ----------------------------------------  0/25 [mpmath]
#    ----------------------------------------  0/25 [mpmath]
#    ----------------------------------------  0/25 [mpmath]
#    ----------------------------------------  0/25 [mpmath]
#    ----------------------------------------  0/25 [mpmath]
#    ----------------------------------------  0/25 [mpmath]
#    ----------------------------------------  0/25 [mpmath]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    - --------------------------------------  1/25 [sympy]
#    --- ------------------------------------  2/25 [shellingham]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ---- -----------------------------------  3/25 [setuptools]
#    ------ ---------------------------------  4/25 [safetensors]
#    -------- -------------------------------  5/25 [pyyaml]
#    -------- -------------------------------  5/25 [pyyaml]
#    -------- -------------------------------  5/25 [pyyaml]
#    -------- -------------------------------  5/25 [pyyaml]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    --------- ------------------------------  6/25 [networkx]
#    ----------- ----------------------------  7/25 [mdurl]
#    ------------ ---------------------------  8/25 [MarkupSafe]
#    -------------- -------------------------  9/25 [hf-xet]
#    ---------------- ----------------------- 10/25 [h11]
#    ---------------- ----------------------- 10/25 [h11]
#    ---------------- ----------------------- 10/25 [h11]
#    ----------------- ---------------------- 11/25 [fsspec]
#    ----------------- ---------------------- 11/25 [fsspec]
#    ----------------- ---------------------- 11/25 [fsspec]
#    ----------------- ---------------------- 11/25 [fsspec]
#    ----------------- ---------------------- 11/25 [fsspec]
#    ----------------- ---------------------- 11/25 [fsspec]
#    ----------------- ---------------------- 11/25 [fsspec]
#    ----------------- ---------------------- 11/25 [fsspec]
#    ----------------- ---------------------- 11/25 [fsspec]
#    ----------------- ---------------------- 11/25 [fsspec]
#    ----------------- ---------------------- 11/25 [fsspec]
#    ----------------- ---------------------- 11/25 [fsspec]
#    ----------------- ---------------------- 11/25 [fsspec]
#    ------------------- -------------------- 12/25 [filelock]
#    ------------------- -------------------- 12/25 [filelock]
#    -------------------- ------------------- 13/25 [anyio]
#    -------------------- ------------------- 13/25 [anyio]
#    -------------------- ------------------- 13/25 [anyio]
#    -------------------- ------------------- 13/25 [anyio]
#    -------------------- ------------------- 13/25 [anyio]
#    -------------------- ------------------- 13/25 [anyio]
#    -------------------- ------------------- 13/25 [anyio]
#    -------------------- ------------------- 13/25 [anyio]
#    -------------------- ------------------- 13/25 [anyio]
#    ------------------------ --------------- 15/25 [markdown-it-py]
#    ------------------------ --------------- 15/25 [markdown-it-py]
#    ------------------------ --------------- 15/25 [markdown-it-py]
#    ------------------------ --------------- 15/25 [markdown-it-py]
#    ------------------------ --------------- 15/25 [markdown-it-py]
#    ------------------------ --------------- 15/25 [markdown-it-py]
#    ------------------------ --------------- 15/25 [markdown-it-py]
#    ------------------------ --------------- 15/25 [markdown-it-py]
#    ------------------------ --------------- 15/25 [markdown-it-py]
#    ------------------------ --------------- 15/25 [markdown-it-py]
#    ------------------------ --------------- 15/25 [markdown-it-py]
#    ------------------------ --------------- 15/25 [markdown-it-py]
#    ------------------------ --------------- 15/25 [markdown-it-py]
#    ------------------------- -------------- 16/25 [jinja2]
#    ------------------------- -------------- 16/25 [jinja2]
#    ------------------------- -------------- 16/25 [jinja2]
#    ------------------------- -------------- 16/25 [jinja2]
#    ------------------------- -------------- 16/25 [jinja2]
#    ------------------------- -------------- 16/25 [jinja2]
#    ------------------------- -------------- 16/25 [jinja2]
#    --------------------------- ------------ 17/25 [httpcore]
#    --------------------------- ------------ 17/25 [httpcore]
#    --------------------------- ------------ 17/25 [httpcore]
#    --------------------------- ------------ 17/25 [httpcore]
#    --------------------------- ------------ 17/25 [httpcore]
#    --------------------------- ------------ 17/25 [httpcore]
#    --------------------------- ------------ 17/25 [httpcore]
#    ---------------------------- ----------- 18/25 [torch]
#    ---------------------------- ----------- 18/25 [torch]
#    ---------------------------- ----------- 18/25 [torch]
#    ---------------------------- ----------- 18/25 [torch]
#    ---------------------------- ----------- 18/25 [torch]
#    ---------------------------- ----------- 18/25 [torch]
#    ---------------------------- ----------- 18/25 [torch]
#    ---------------------------- ----------- 18/25 [torch]
#    ---------------------------- ----------- 18/25 [torch]
#    ---------------------------- ----------- 18/25 [torch]
#    ---------------------------- ----------- 18/25 [torch]
#    ---------------------------- ----------- 18/25 [torch]
#    ---------------------------- ----------- 18/25 [torch]
#    ---------------------------- ----------- 18/25 [torch]
#    ---------------------------- ----------- 18/25 [torch]
#    ---------------------------- ----------- 18/25 [torch]
#    ---------------------------- ----------- 18/25 [torch]
#    ---------------------------- ----------- 18/25 [torch]
#    ---------------------------- ----------- 18/25 [torch]
#    ---------------------------- ----------- 18/25 [torch]
#    ---------------------------- ----------- 18/25 [torch]
#    ---------------------------- ----------- 18/25 [torch]
#    ---------------------------- ----------- 18/25 [torch]
#    ---------------------------- ----------- 18/25 [torch]
#    ---------------------------- ----------- 18/25 [torch]
#    ---------------------------- ----------- 18/25 [torch]
# ...
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    -------------------------------------- - 24/25 [transformers]
#    ---------------------------------------- 25/25 [transformers]
#
# Successfully installed MarkupSafe-3.0.3 annotated-doc-0.0.4 anyio-4.12.1 filelock-3.25.0 fsspec-2026.2.0 h11-0.16.0 hf-xet-1.3.2 httpcore-1.0.9 httpx-0.28.1 huggingface-hub-1.6.0 jinja2-3.1.6 markdown-it-py-4.0.0 mdurl-0.1.2 mpmath-1.3.0 networkx-3.6.1 pyyaml-6.0.3 rich-14.3.3 safetensors-0.7.0 setuptools-82.0.0 shellingham-1.5.4 sympy-1.14.0 tokenizers-0.22.2 torch-2.10.0 transformers-5.3.0 typer-0.24.1
#   WARNING: The script isympy.exe is installed in 'C:\Users\lenovo\AppData\Roaming\Python\Python314\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown-it.exe is installed in 'C:\Users\lenovo\AppData\Roaming\Python\Python314\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts torchfrtrace.exe and torchrun.exe are installed in 'C:\Users\lenovo\AppData\Roaming\Python\Python314\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script httpx.exe is installed in 'C:\Users\lenovo\AppData\Roaming\Python\Python314\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script typer.exe is installed in 'C:\Users\lenovo\AppData\Roaming\Python\Python314\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts hf.exe and tiny-agents.exe are installed in 'C:\Users\lenovo\AppData\Roaming\Python\Python314\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script transformers.exe is installed in 'C:\Users\lenovo\AppData\Roaming\Python\Python314\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Program Files\Python314\python.exe -m pip install --upgrade pip

# %%
from transformers import pipeline
model_path = "cardiffnlp/twitter-xlm-roberta-base-sentiment"
sentiment_analyzer = pipeline("sentiment-analysis", model=model_path, tokenizer=model_path)

print("Model successfully loaded!")

# %%
hindi_sentences = [
    # Translation: "This movie is very brilliant and I liked it a lot."
    "यह फिल्म बहुत शानदार है और मुझे यह बहुत पसंद आई।",

    # Translation: "The customer service was very bad and my experience was disappointing."
    "ग्राहक सेवा बहुत खराब थी और मेरा अनुभव निराशाजनक रहा।",

    # Translation: "I will go to the market tomorrow and buy some vegetables."
    "मैं कल बाजार जाकर कुछ सब्जियां खरीदूंगा।"
]

# %%
print("--- Hindi Sentiment Analysis Results ---\n")

for sentence in hindi_sentences:
    result = sentiment_analyzer(sentence)[0]
    label = result['label'].upper()
    confidence = result['score']

    print(f"Text: {sentence}")
    print(f"Predicted Sentiment: {label}")
    print(f"Confidence Score:  {confidence:.2%}\n")
# Out:
# --- Hindi Sentiment Analysis Results ---
#
# Text: यह फिल्म बहुत शानदार है और मुझे यह बहुत पसंद आई।
# Predicted Sentiment: POSITIVE
# Confidence Score:  92.96%
#
# Text: ग्राहक सेवा बहुत खराब थी और मेरा अनुभव निराशाजनक रहा।
# Predicted Sentiment: NEGATIVE
# Confidence Score:  94.39%
#
# Text: मैं कल बाजार जाकर कुछ सब्जियां खरीदूंगा।
# Predicted Sentiment: NEUTRAL
# Confidence Score:  49.10%
